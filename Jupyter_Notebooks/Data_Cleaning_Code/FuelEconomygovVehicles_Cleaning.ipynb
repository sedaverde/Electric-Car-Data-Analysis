# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
file_path = ("C:/Users/adaiu/OneDrive/Desktop/Analysis Projects/Electric-Car-Data-Analysis/Resources/Mileage/FuelEconomygovVehicles.csv")
fuel_eco_df = pd.read_csv(file_path)
fuel_eco_df.head()
# Out:
# C:\Users\adaiu\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3166: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  14.167143         0.0          0        0.0      19      0.0        0
# 1  27.046364         0.0          0        0.0       9      0.0        0
# 2  11.018889         0.0          0        0.0      23      0.0        0
# 3  27.046364         0.0          0        0.0      10      0.0        0
# 4  15.658421         0.0          0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...

# %%
fuel_eco_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44763 entries, 0 to 44762
# Data columns (total 83 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        44763 non-null  float64
#  1   barrelsA08       44763 non-null  float64
#  2   charge120        44763 non-null  int64
#  3   charge240        44763 non-null  float64
#  4   city08           44763 non-null  int64
#  5   city08U          44763 non-null  float64
#  6   cityA08          44763 non-null  int64
#  7   cityA08U         44763 non-null  float64
#  8   cityCD           44763 non-null  float64
#  9   cityE            44763 non-null  float64
#  10  cityUF           44763 non-null  float64
#  11  co2              44763 non-null  int64
#  12  co2A             44763 non-null  int64
#  13  co2TailpipeAGpm  44763 non-null  float64
#  14  co2TailpipeGpm   44763 non-null  float64
#  15  comb08           44763 non-null  int64
# ...

# %%
fuel_eco_df.dtypes.value_counts()
# Out:
# float64    31
# int64      28
# object     23
# bool        1
# dtype: int64

# %%
fuel_eco_df = fuel_eco_df[["year", "make", "model", "trany", "rangeCity", "rangeHwy", "highway08"]]
fuel_eco_df.head()
# Out:
#    year        make                model            trany  rangeCity  \
# 0  1985  Alfa Romeo   Spider Veloce 2000     Manual 5-spd        0.0
# 1  1985     Ferrari           Testarossa     Manual 5-spd        0.0
# 2  1985       Dodge              Charger     Manual 5-spd        0.0
# 3  1985       Dodge  B150/B250 Wagon 2WD  Automatic 3-spd        0.0
# 4  1993      Subaru     Legacy AWD Turbo     Manual 5-spd        0.0
#
#    rangeHwy  highway08
# 0       0.0         25
# 1       0.0         14
# 2       0.0         33
# 3       0.0         12
# 4       0.0         23

# %%
fuel_eco_df.dtypes
# Out:
# year           int64
# make          object
# model         object
# trany         object
# rangeCity    float64
# rangeHwy     float64
# highway08      int64
# dtype: object

# %%
fuel_eco_df.drop(fuel_eco_df.loc[fuel_eco_df["year"] < 2010].index, inplace = True)

# %%
fuel_eco_df.nunique()
# Out:
# year           14
# make           71
# model        2616
# trany          34
# rangeCity     166
# rangeHwy      164
# highway08     108
# dtype: int64

# %%
fuel_eco_df.sort_values(by= ['make','year'], inplace = True)
fuel_eco_df
# Out:
#        year   make                              model           trany  \
# 20445  2010  Acura                                TSX    Manual 6-spd
# 20446  2010  Acura                                TSX  Automatic (S5)
# 20447  2010  Acura                                TSX  Automatic (S5)
# 20498  2010  Acura                                 RL  Automatic (S5)
# 21291  2010  Acura                            RDX 2WD  Automatic (S5)
# ...     ...    ...                                ...             ...
# 32528  2017  smart  fortwo electric drive convertible  Automatic (A1)
# 32728  2018  smart        fortwo electric drive coupe  Automatic (A1)
# 32729  2018  smart  fortwo electric drive convertible  Automatic (A1)
# 34280  2019  smart                  EQ fortwo (coupe)  Automatic (A1)
# 34281  2019  smart            EQ fortwo (convertible)  Automatic (A1)
#
#        rangeCity  rangeHwy  highway08
# 20445        0.0       0.0         28
# 20446        0.0       0.0         30
# ...

# %%
fuel_eco_df.reset_index(drop = True, inplace = True)
fuel_eco_df.head()
# Out:
#    year   make    model           trany  rangeCity  rangeHwy  highway08
# 0  2010  Acura      TSX    Manual 6-spd        0.0       0.0         28
# 1  2010  Acura      TSX  Automatic (S5)        0.0       0.0         30
# 2  2010  Acura      TSX  Automatic (S5)        0.0       0.0         27
# 3  2010  Acura       RL  Automatic (S5)        0.0       0.0         22
# 4  2010  Acura  RDX 2WD  Automatic (S5)        0.0       0.0         24

# %%
filepath = ("C:/Users/adaiu/OneDrive/Desktop/Analysis Projects/Electric-Car-Data-Analysis/Resources/Mileage/Cleaned_dataset/FuelEconomygovVehicles_Cleaned.csv")
fuel_eco_df.to_csv(filepath, index = False)
