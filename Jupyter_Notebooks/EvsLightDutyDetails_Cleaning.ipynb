# %%
import pandas as pd

# %%
file_path = (r"C:\Users\adaiu\OneDrive\Desktop\Analysis Projects\Electric-Car-Data-Analysis\Resources\EVs\EvsLightDutyDetails.csv")
light_duty_details_df = pd.read_csv(file_path)
light_duty_details_df.head()
# Out:
#    Vehicle ID  Fuel ID  Fuel Configuration ID  Manufacturer ID  Category ID  \
# 0       13044       45                    9.0              365           27
# 1       12854       45                    9.0              377           27
# 2       12842       45                    9.0              377           27
# 3       12783       45                    9.0              377           27
# 4       12782       45                    9.0              377           27
#
#                 Model  Model Year  Alternative Fuel Economy City  \
# 0                 NSX        2022                            NaN
# 1                 A3         2022                            NaN
# 2          A3 quattro        2022                            NaN
# 3  A4 allroad quattro        2022                            NaN
# 4          A4 quattro        2022                            NaN
#
#    Alternative Fuel Economy Highway  Alternative Fuel Economy Combined  ...  \
# ...

# %%
light_duty_details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1439 entries, 0 to 1438
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Vehicle ID                          1439 non-null   int64
#  1   Fuel ID                             1439 non-null   int64
#  2   Fuel Configuration ID               1406 non-null   float64
#  3   Manufacturer ID                     1439 non-null   int64
#  4   Category ID                         1439 non-null   int64
#  5   Model                               1439 non-null   object
#  6   Model Year                          1439 non-null   int64
#  7   Alternative Fuel Economy City       565 non-null    float64
#  8   Alternative Fuel Economy Highway    474 non-null    float64
#  9   Alternative Fuel Economy Combined   335 non-null    float64
#  10  Conventional Fuel Economy City      927 non-null    float64
# ...

# %%
light_duty_details_df.columns
# Out:
# Index(['Vehicle ID', 'Fuel ID', 'Fuel Configuration ID', 'Manufacturer ID',
#        'Category ID', 'Model', 'Model Year', 'Alternative Fuel Economy City',
#        'Alternative Fuel Economy Highway', 'Alternative Fuel Economy Combined',
#        'Conventional Fuel Economy City', 'Conventional Fuel Economy Highway',
#        'Conventional Fuel Economy Combined', 'Transmission Type',
#        'Engine Type', 'Engine Size', 'Engine Cylinder Count',
#        'Engine Description', 'Manufacturer', 'Manufacturer URL', 'Category',
#        'Fuel Code', 'Fuel', 'Fuel Configuration Name', 'Electric-Only Range',
#        'PHEV Type', 'Notes', 'Drivetrain'],
#       dtype='object')

# %%
light_duty_details_df = light_duty_details_df[['Model Year','Model','Manufacturer','Manufacturer ID','Vehicle ID','Category',
                                               'Fuel','Fuel ID','Transmission Type', 'Engine Description',]]

light_duty_details_df.head()
# Out:
#    Model Year               Model Manufacturer  Manufacturer ID  Vehicle ID  \
# 0        2022                 NSX        Acura              365       13044
# 1        2022                 A3          Audi              377       12854
# 2        2022          A3 quattro         Audi              377       12842
# 3        2022  A4 allroad quattro         Audi              377       12783
# 4        2022          A4 quattro         Audi              377       12782
#
#       Category             Fuel  Fuel ID Transmission Type Engine Description
# 0  Sedan/Wagon  Hybrid Electric       45              Auto            3.5L V6
# 1  Sedan/Wagon  Hybrid Electric       45              Auto            2.0L I4
# 2  Sedan/Wagon  Hybrid Electric       45              Auto            2.0L I4
# 3  Sedan/Wagon  Hybrid Electric       45              Auto            2.0L I4
# 4  Sedan/Wagon  Hybrid Electric       45              Auto            2.0L I4

# %%
light_duty_details_df.drop(light_duty_details_df.loc[light_duty_details_df["Model Year"] < 2010].index, inplace = True)
light_duty_details_df.head()
# Out:
#    Model Year               Model Manufacturer  Manufacturer ID  Vehicle ID  \
# 0        2022                 NSX        Acura              365       13044
# 1        2022                 A3          Audi              377       12854
# 2        2022          A3 quattro         Audi              377       12842
# 3        2022  A4 allroad quattro         Audi              377       12783
# 4        2022          A4 quattro         Audi              377       12782
#
#       Category             Fuel  Fuel ID Transmission Type Engine Description
# 0  Sedan/Wagon  Hybrid Electric       45              Auto            3.5L V6
# 1  Sedan/Wagon  Hybrid Electric       45              Auto            2.0L I4
# 2  Sedan/Wagon  Hybrid Electric       45              Auto            2.0L I4
# 3  Sedan/Wagon  Hybrid Electric       45              Auto            2.0L I4
# 4  Sedan/Wagon  Hybrid Electric       45              Auto            2.0L I4

# %%
light_duty_details_df.dtypes
# Out:
# Model Year             int64
# Model                 object
# Manufacturer          object
# Manufacturer ID        int64
# Vehicle ID             int64
# Category              object
# Fuel                  object
# Fuel ID                int64
# Transmission Type     object
# Engine Description    object
# dtype: object

# %%
light_duty_details_df.rename(columns = {'Model Year':'Model_Year', 'Manufacturer ID':'ManufacturerID',
                                        'Vehicle ID':'VehicleID', 'Fuel ID':'FuelID', 'Transmission Type':'Transmission_Type',
                                        'Engine Description':'Engine_Description'}, inplace = True)
light_duty_details_df.head()
# Out:
#    Model_Year               Model Manufacturer  ManufacturerID  VehicleID  \
# 0        2022                 NSX        Acura             365      13044
# 1        2022                 A3          Audi             377      12854
# 2        2022          A3 quattro         Audi             377      12842
# 3        2022  A4 allroad quattro         Audi             377      12783
# 4        2022          A4 quattro         Audi             377      12782
#
#       Category             Fuel  FuelID Transmission_Type Engine_Description
# 0  Sedan/Wagon  Hybrid Electric      45              Auto            3.5L V6
# 1  Sedan/Wagon  Hybrid Electric      45              Auto            2.0L I4
# 2  Sedan/Wagon  Hybrid Electric      45              Auto            2.0L I4
# 3  Sedan/Wagon  Hybrid Electric      45              Auto            2.0L I4
# 4  Sedan/Wagon  Hybrid Electric      45              Auto            2.0L I4

# %%
light_duty_details_df.sort_values(by=['Model_Year', 'Model', 'Manufacturer'], inplace=True)
light_duty_details_df.reset_index(inplace=True, drop= True)
light_duty_details_df.head()
# Out:
#    Model_Year            Model Manufacturer  ManufacturerID  VehicleID  \
# 0        2010           Altima       Nissan             217        941
# 1        2010            Camry       Toyota             221        943
# 2        2010     Civic Hybrid        Honda             209        935
# 3        2010  Escalade Hybrid     Cadillac             231        946
# 4        2010    Escape Hybrid         Ford             219        945
#
#       Category             Fuel  FuelID Transmission_Type Engine_Description
# 0  Sedan/Wagon  Hybrid Electric      45         Automatic                NaN
# 1  Sedan/Wagon  Hybrid Electric      45         Automatic                NaN
# 2  Sedan/Wagon  Hybrid Electric      45         Automatic                NaN
# 3          SUV  Hybrid Electric      45         Automatic                NaN
# 4          SUV  Hybrid Electric      45         Automatic                NaN

# %%
filepath = (r"C:\Users\adaiu\OneDrive\Desktop\Analysis Projects\Electric-Car-Data-Analysis\Resources\EVs\Cleaned_datasets\EvsLightDutyDetails_Cleaned.csv")
light_duty_details_df.to_csv(filepath, index = False)
