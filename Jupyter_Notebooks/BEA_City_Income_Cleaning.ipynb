# %%
import pandas as pd

# %%
file_path = (r"C:\Users\adaiu\OneDrive\Desktop\Analysis Projects\Electric-Car-Data-Analysis\Resources\Income\BEA City Income 2018-2020.xlsx")
bea_city_income_df = pd.read_excel(file_path)
bea_city_income_df.head()
# Out:
#   Table 2. Per Capita Personal Income, by Metropolitan Area, 2018–2020  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                      United States
# 4                               Metropolitan portion
#
#                     Unnamed: 1  Unnamed: 2  Unnamed: 3             Unnamed: 4  \
# 0  Per capita personal income1         NaN         NaN                    NaN
# 1                      Dollars         NaN         NaN  Rank in United States
# 2                         2018      2019.0      2020.0                   2020
# 3                        54098     56047.0     59510.0                     --
# 4                        56179     58196.0     61674.0                     --
#
#                              Unnamed: 5  Unnamed: 6             Unnamed: 7
# 0  Percent change from preceding period         NaN                    NaN
# ...
